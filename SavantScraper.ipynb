# %%
import numpy as np
import pandas as pd
from datetime import datetime
from urllib.error import HTTPError
# from tqdm.notebook import tqdm
from time import sleep
import pickle as pkl
import seaborn as sns

# %%
# file_name = 'pitchers_since_2018.txt'
# file_name = 'pitchers_no_TJ.txt'
# raw_file = pd.read_csv(file_name, sep='\t')
# raw_file[2].apply(str.strip)

# %%
# raw_file.columns = ['First Name', 'Last Name', 'Position', 'Handedness', 'Month', 'Year', 'Year2', 'Note']
def preprocess(raw_f):
    f = raw_f.copy()
    f = f[f['Position'] == 'P']
    f['Date'] = f['Date'].apply(lambda x : datetime.strptime(x, '%m/%d/%Y'))
    f['Season'] = f['Date'].apply(lambda x: x.year)
    return f

def gen_seasons(last_season, years_back):
    s = str(last_season)
    for i in range(1, years_back):
        s += f'|{last_season - i}'
    return s

# This scraper based off of: https://github.com/alanrkessler/savantscraper/blob/master/savantscraper.py
def get_pitches(Id, name, num_tries=5, pause_time=30):
    # Id = entry['Id']
    # season = entry['Season']
    # name = entry['Player'].replace(" ", "")
    seasons = gen_seasons(2022, 2022-2016)
    
    url = ("https://baseballsavant.mlb.com/statcast_search/csv?all=true"
           "&hfPT=&hfAB=&hfBBT=&hfPR=&hfZ=&stadium=&hfBBL=&hfNewZones=&hfGT=R|&h"
           f"fC=&hfSea={seasons}%7C&hfSit=&player_type=pitcher&hfOuts=&opponent"
           "=&pitcher_throws=&batter_stands=&hfSA=&game_date_gt=&game_date_lt="
           f"&hfInfield=&team=&position=&hfOutfield=&hfRO="
           f"&home_road=&hfFlag=&hfPull=&pitchers_lookup[]={Id}&metric_1=&hfInn="
           "&min_pitches=0&min_results=0&group_by=name&sort_col=pitches"
           "&player_event_sort=pitch_number_thisgame&sort_order=desc"
           "&min_pas=0&type=details&")
    
    for i in range(num_tries):
        try:
            pitch_data = pd.read_csv(url, low_memory=False)
        except HTTPError as connect_error:
            if connect_error:
                if retry >= num_tries - 1:
                    raise HTTPError
                else:
                    sleep(pause_time)
                    pause_time *= 2
                    continue
            else:
                break
    
    # pitch_data.to_csv(f"scraped_data/{name}.csv")
    return pitch_data

# %%
with open('ids_by_name.pkl', 'rb') as f:
    ids_by_name = pkl.load(f)
    
with open('inj_by_name.pkl', 'rb') as f:
    inj_by_name = pkl.load(f)

# %%
for name, inj_list in inj_by_name.items():
    df = get_pitches(ids_by_name[name], name)
    if len(inj_list) == 0:
        continue
    inj_list = np.vectorize(np.datetime64)(inj_list)
    df['game_date'] = pd.to_datetime(df['game_date'], unit='ns')
    dates = df['game_date'].unique()
    dates.sort()
    df['injury_day'] = 0
    for injury_date in inj_list:
        previous_dates = dates[dates < injury_date]
        try:
            outing_date = max(previous_dates)
            df.loc[df['game_date'] == outing_date, 'injury_day'] = 1
        except:
            print(f'No outing prior to {injury_date}')
    df.to_csv(f"scraped_data/{name}.csv", index=False)
# Out:
# No outing prior to 2015-04-26T00:00:00.000000
# No outing prior to 2011-03-25T00:00:00.000000
# No outing prior to 2015-04-08T00:00:00.000000
# No outing prior to 2013-08-06T00:00:00.000000
# No outing prior to 2015-05-11T00:00:00.000000
# No outing prior to 2014-08-09T00:00:00.000000
# No outing prior to 2017-06-22T00:00:00.000000
# No outing prior to 2017-04-06T00:00:00.000000
# No outing prior to 2015-04-08T00:00:00.000000
# No outing prior to 2014-07-01T00:00:00.000000
# No outing prior to 2018-05-12T00:00:00.000000
# No outing prior to 2015-05-18T00:00:00.000000
# No outing prior to 2016-06-14T00:00:00.000000
# No outing prior to 2018-04-03T00:00:00.000000
# No outing prior to 2019-04-04T00:00:00.000000
# No outing prior to 2018-06-27T00:00:00.000000
# No outing prior to 2017-04-25T00:00:00.000000
# No outing prior to 2016-08-25T00:00:00.000000
# No outing prior to 2015-08-18T00:00:00.000000
# No outing prior to 2013-06-25T00:00:00.000000
# No outing prior to 2017-09-06T00:00:00.000000
# No outing prior to 2017-05-19T00:00:00.000000
# No outing prior to 2017-05-26T00:00:00.000000
# No outing prior to 2015-05-11T00:00:00.000000
# No outing prior to 2019-06-24T00:00:00.000000
# No outing prior to 2019-04-15T00:00:00.000000
# No outing prior to 2018-04-05T00:00:00.000000
# No outing prior to 2017-08-08T00:00:00.000000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
#       1 for name, inj_list in inj_by_name.items():
#       2     df = get_pitches(ids_by_name[name], name)
# ----> 4     inj_list = np.vectorize(np.datetime64)(inj_list)
#       5     df['game_date'] = pd.to_datetime(df['game_date'], unit='ns')
#       6     dates = df['game_date'].unique()
#
# File ~\anaconda3\envs\jlab\lib\site-packages\numpy\lib\function_base.py:2328, in vectorize.__call__(self, *args, **kwargs)
#    2325     vargs = [args[_i] for _i in inds]
#    2326     vargs.extend([kwargs[_n] for _n in names])
# -> 2328 return self._vectorize_call(func=func, args=vargs)
#
# File ~\anaconda3\envs\jlab\lib\site-packages\numpy\lib\function_base.py:2406, in vectorize._vectorize_call(self, func, args)
#    2404     res = func()
#    2405 else:
# -> 2406     ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2408     # Convert args to object arrays first
#    2409     inputs = [asanyarray(a, dtype=object) for a in args]
#
# File ~\anaconda3\envs\jlab\lib\site-packages\numpy\lib\function_base.py:2362, in vectorize._get_ufunc_and_otypes(self, func, args)
#    2360 args = [asarray(arg) for arg in args]
#    2361 if builtins.any(arg.size == 0 for arg in args):
# -> 2362     raise ValueError('cannot call `vectorize` on size 0 inputs '
#    2363                      'unless `otypes` is set')
#    2365 inputs = [arg.flat[0] for arg in args]
#    2366 outputs = func(*inputs)
#
# ValueError: cannot call `vectorize` on size 0 inputs unless `otypes` is set

# %%
test = pd.read_csv(f'scraped_data/{name}.csv')

# %%
test.head()
# Out:
#    Unnamed: 0 pitch_type   game_date  release_speed  release_pos_x  \
# 0           0         FC  2022-06-22           85.8          -1.06
# 1           1         FC  2022-06-22           84.4          -1.08
# 2           2         FC  2022-06-22           85.8          -1.06
# 3           3         FF  2022-06-22           88.1          -1.25
# 4           4         CU  2022-06-22           72.8          -1.23
#
#    release_pos_z       player_name  batter  pitcher  events  ...  \
# 0           6.26  Wainwright, Adam  457705   425794  double  ...
# 1           6.33  Wainwright, Adam  457705   425794     NaN  ...
# 2           6.31  Wainwright, Adam  457705   425794     NaN  ...
# 3           6.18  Wainwright, Adam  642133   425794    walk  ...
# 4           6.33  Wainwright, Adam  642133   425794     NaN  ...
#
#   post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0               3                4               4               3
# 1               3                3               3               3
# 2               3                3               3               3
# 3               3                3               3               3
# 4               3                3               3               3
#
#    if_fielding_alignment  of_fielding_alignment spin_axis delta_home_win_exp  \
# 0          Infield shift               Standard     153.0              0.163
# 1          Infield shift               Standard     142.0              0.000
# 2          Infield shift               Standard     160.0              0.000
# 3              Strategic               Standard     193.0              0.011
# 4              Strategic               Standard      43.0              0.000
#
#   delta_run_exp injury_day
# 0         1.721          0
# 1        -0.095          0
# 2        -0.060          0
# 3         0.045          0
# 4         0.058          0
#
# [5 rows x 94 columns]

# %%
tj_data = preprocess(raw_file)

# %%
example = get_pitches(tj_data.iloc[0])

# %%
for i in tqdm(range(len(tj_data))):
    example = get_pitches(tj_data.iloc[i])
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]

# %%
example
# Out:
#     pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0           FF  2017-09-28           94.7           2.12           5.81
# 1           CU  2017-09-28           78.4           2.30           5.85
# 2           CU  2017-09-28           81.2           2.30           5.59
# 3           CU  2017-09-28           82.4           2.47           5.65
# 4           FF  2017-09-28           94.3           2.16           5.57
# ..         ...         ...            ...            ...            ...
# 318         FF  2017-06-11           92.9           1.88           6.14
# 319         FF  2017-06-11           92.0           1.96           6.20
# 320         FF  2017-06-11           94.1           1.79           6.21
# 321         FF  2017-06-11           92.4           1.85           6.14
# 322         FF  2017-06-11           92.8           1.80           6.10
#
#      player_name  batter  pitcher     events    description  ...  fld_score  \
# 0    Turley, Nik  467793   543867  field_out  hit_into_play  ...          0
# 1    Turley, Nik  467793   543867        NaN           ball  ...          0
# 2    Turley, Nik  467793   543867        NaN  called_strike  ...          0
# 3    Turley, Nik  467793   543867        NaN           ball  ...          0
# 4    Turley, Nik  457803   543867   home_run  hit_into_play  ...          0
# ..           ...     ...      ...        ...            ...  ...        ...
# 318  Turley, Nik  605509   543867     single  hit_into_play  ...          0
# 319  Turley, Nik  605509   543867        NaN           ball  ...          0
# 320  Turley, Nik  605509   543867        NaN           ball  ...          0
# 321  Turley, Nik  605509   543867        NaN  called_strike  ...          0
# 322  Turley, Nik  605509   543867        NaN           ball  ...          0
#
#      post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0                  0                5               5               0
# 1                  0                5               5               0
# 2                  0                5               5               0
# 3                  0                5               5               0
# 4                  0                5               5               0
# ..               ...              ...             ...             ...
# 318                0                0               0               0
# 319                0                0               0               0
# 320                0                0               0               0
# 321                0                0               0               0
# 322                0                0               0               0
#
#     if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 0                Standard              Standard       164              0.000
# 1                Standard              Standard       319              0.000
# 2                Standard              Standard       303              0.000
# 3                Standard              Standard       296              0.000
# 4           Infield shift             Strategic       148              0.007
# ..                    ...                   ...       ...                ...
# 318              Standard              Standard       143              0.036
# 319              Standard              Standard       151              0.000
# 320              Standard              Standard       145              0.000
# 321              Standard              Standard       144              0.000
# 322              Standard              Standard       153              0.000
#
#     delta_run_exp
# 0          -0.121
# 1           0.020
# 2          -0.022
# 3           0.018
# 4           0.982
# ..            ...
# 318         0.229
# 319         0.117
# 320         0.050
# 321        -0.046
# 322         0.036
#
# [323 rows x 92 columns]
